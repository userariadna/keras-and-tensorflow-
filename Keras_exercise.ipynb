# %%
# !wget https://raw.githubusercontent.com/IBM/coursera/master/coursera_ai/AssignmentKeras.ipynb
# Out:
# --2020-08-03 18:04:53--  https://raw.githubusercontent.com/IBM/coursera/master/coursera_ai/AssignmentKeras.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.8.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.8.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9439 (9.2K) [text/plain]
# Saving to: ‘AssignmentKeras.ipynb.1’
#
# 100%[======================================>] 9,439       --.-K/s   in 0s
#
# 2020-08-03 18:04:54 (63.4 MB/s) - ‘AssignmentKeras.ipynb.1’ saved [9439/9439]

# %%
# !pip install tensorflow==2.2.0rc0
# Out:
# ...
#      |████████████████████████████████| 798kB 12.8MB/s eta 0:00:01
# ...
# ERROR: tensorboard 2.1.1 has requirement grpcio>=1.24.3, but you'll have grpcio 1.16.1 which is incompatible.
# ...
#   Found existing installation: setuptools 40.8.0
#     Uninstalling setuptools-40.8.0:
#       Successfully uninstalled setuptools-40.8.0
# ...

# %%
import tensorflow as tf
if not tf.__version__ == '2.2.0-rc0':
    print(tf.__version__)
    raise ValueError('please upgrade to TensorFlow 2.2.0-rc0, or restart your Kernel (Kernel->Restart & Clear Output)')
# Out:
# 1.13.1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-87fb5718b0db> in <module>
#       2 if not tf.__version__ == '2.2.0-rc0':
#       3     print(tf.__version__)
# ----> 4     raise ValueError('please upgrade to TensorFlow 2.2.0-rc0, or restart your Kernel (Kernel->Restart & Clear Output)')
#
# ValueError: please upgrade to TensorFlow 2.2.0-rc0, or restart your Kernel (Kernel->Restart & Clear Output)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout 
from tensorflow.keras.utils import to_categorical
seed = 1337
np.random.seed(seed)
from tensorflow.keras.datasets import reuters

max_words = 1000
(x_train, y_train), (x_test,y_test) = reuters.load_data(num_words=max_words,
                                                        test_split=0.2,
                                                        seed=seed)
    
num_classes = np.max(y_train) + 1
# Out:
# ...
# 2113536/2110848 [==============================] - 0s 0us/step

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=max_words)
x_train = tokenizer.sequences_to_matrix(x_train, mode ='binary')
x_test = tokenizer.sequences_to_matrix(x_test,mode='binary')

# %%
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Dense(512,activation='relu',
               input_shape=(max_words,)))
model.add(Dropout(0,5))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics = ['accuracy'])

# %%
model.fit(x_train, y_train,
      batch_size = 32, epochs=5)
score = model.evaluate(x_test,y_test, batch_size=32)
# Out:
# WARNING:tensorflow:From /opt/conda/envs/Python36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/5
# 8982/8982 [==============================] - 40s 4ms/sample - loss: 1.2259 - acc: 0.7242
# Epoch 2/5
# 8982/8982 [==============================] - 41s 5ms/sample - loss: 0.5845 - acc: 0.8661
# Epoch 3/5
# 8982/8982 [==============================] - 30s 3ms/sample - loss: 0.3794 - acc: 0.9060
# Epoch 4/5
# 8982/8982 [==============================] - 35s 4ms/sample - loss: 0.2822 - acc: 0.9293
# Epoch 5/5
# ...
# 2246/2246 [==============================] - 1s 384us/sample - loss: 0.9229 - acc: 0.7921

# %%
score[1]
# Out:
# 0.7920748

# %%
# !rm -f rklib.py
# !wget https://raw.githubusercontent.com/IBM/coursera/master/rklib.py
# Out:
# --2020-08-04 04:19:29--  https://raw.githubusercontent.com/IBM/coursera/master/rklib.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2540 (2.5K) [text/plain]
# Saving to: ‘rklib.py’
#
# 100%[======================================>] 2,540       --.-K/s   in 0s
#
# 2020-08-04 04:19:29 (25.9 MB/s) - ‘rklib.py’ saved [2540/2540]

# %%
from rklib import submit
import json

key = "XbAMqtjdEeepUgo7OOVwng"
part = "HCvcp"
email = "ariadnaelizabeth3@gmail.com"
token = "uZjtXK52v9dMcht7"


submit(email, token, 'XbAMqtjdEeepUgo7OOVwng', part, [part], json.dumps(score[1]*100))
# Out:
# Submission successful, please check on the coursera grader page for the status
# -------------------------
# {"elements":[{"itemId":"ozVf2","id":"tE4j0qhMEeecqgpT6QjMdA~ozVf2~xbTuS9YJEeqUhhLc5hJ2Ww","courseId":"tE4j0qhMEeecqgpT6QjMdA"}],"paging":{},"linked":{}}
# -------------------------
